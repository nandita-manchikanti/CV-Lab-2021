# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
#from google.colab.patches import cv2_imshow

# %%
imgR = cv2.imread('right7.jpg',0)
imgL = cv2.imread('left7.jpg',0)
stereo = cv2.StereoBM_create(16,11)
disparity = stereo.compute(imgL, imgR)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left6.jpg',0)
imgR = cv2.imread('right6.jpg',0)
stereo = cv2.StereoBM_create(96, 15)
disparity = stereo.compute(imgL, imgR)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left4.jpg',0)
imgR = cv2.imread('right4.jpg',0)
stereo = cv2.StereoBM_create(48,15)
disparity = stereo.compute(imgL, imgR)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left2.jpg',0)
imgR = cv2.imread('right2.jpg',0)
stereo = cv2.StereoBM_create(64,21)
disparity = stereo.compute(imgR, imgL)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left5.jpg',0)
imgR = cv2.imread('right5.jpg',0)
stereo = cv2.StereoBM_create(64,21)
disparity = stereo.compute(imgL, imgR)
plt.imshow(imgL, cmap='gray')	
plt.show()
plt.imshow(imgR, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left8.jpg',0)
imgR = cv2.imread('right8.jpg',0)
stereo = cv2.StereoBM_create(16,15)
disparity = stereo.compute(imgL, imgR)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left9.jpg',0)
imgR = cv2.imread('right9.jpg',0)
stereo = cv2.StereoBM_create(48,23)
disparity = stereo.compute(imgR,imgL)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()

# %%
imgL = cv2.imread('left10.jpg',0)
imgR = cv2.imread('right10.jpg',0)
stereo = cv2.StereoBM_create(64,23)
disparity = stereo.compute(imgL, imgR)
plt.imshow(imgR, cmap='gray')	
plt.show()
plt.imshow(imgL, cmap='gray')
plt.show()
plt.imshow(disparity)
plt.show()
