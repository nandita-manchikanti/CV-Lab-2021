# %%
def segment(path):
  import numpy as np
  import cv2
  import matplotlib.pyplot as plt

  img = cv2.imread(path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  
  print("Actual Image")
  plt.imshow(img)
  plt.show()

  Z = img.reshape((-1,3))

  Z = np.float32(Z)

  criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
  K = 3
  ret,label,center=cv2.kmeans(Z,K,None,criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
 
  center = np.uint8(center)
  res = center[label.flatten()]
  res2 = res.reshape((img.shape))
  print("K-Means Clustering")
  plt.imshow(res2)
  plt.show()

  labels=list(label)

  centroid=center
  print(centroid)

  percent=[]
  for i in range(len(centroid)):
    j=labels.count(i)
    j=j/(len(labels))
    percent.append(j)
  print("Percentages of each color")
  print(percent)

  plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
  plt.show()

  percent.sort()
  print(percent)
  ans=(percent[0])/(percent[1]+percent[0])
  print("Percentage of postivity")
  print(ans*100)
  if(ans*100>15):
    print("High Grade")
  else:
    print("Low Grade")

# %%
segment('1714 KI67.jpg')
segment('1718 KI67.jpg')
segment('2141 KI67.jpg')
segment('3053 KI67.jpg')
# Out:
# Actual Image
# K-Means Clustering
# [[143 112 119]
#  [166 163 176]
#  [190 188 187]]
# Percentages of each color
# [0.04537495930989583, 0.3195111083984375, 0.6351139322916667]
# [0.04537495930989583, 0.3195111083984375, 0.6351139322916667]
# Percentage of postivity
# 12.4353773206177
# Low Grade
# Actual Image
# K-Means Clustering
# [[184 181 188]
#  [150 148 175]
#  [100  74 118]]
# Percentages of each color
# [0.5472243245442708, 0.40756368001302085, 0.04521199544270833]
# [0.04521199544270833, 0.40756368001302085, 0.5472243245442708]
# Percentage of postivity
# 9.985517750528762
# Low Grade
# Actual Image
# K-Means Clustering
# [[182 174 168]
#  [103  60  79]
#  [156 143 144]]
# Percentages of each color
# [0.7021968587239583, 0.06496988932291667, 0.232833251953125]
# [0.06496988932291667, 0.232833251953125, 0.7021968587239583]
# Percentage of postivity
# 21.816388183324882
# High Grade
# Actual Image
# K-Means Clustering
# [[117  78  68]
#  [145 139 152]
#  [160 157 161]]
# ...
